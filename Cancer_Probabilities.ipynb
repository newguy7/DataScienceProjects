# %% [markdown]
# <a href="https://colab.research.google.com/github/newguy7/DataScienceProjects/blob/main/Cancer_Probabilities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement
# ### The project is to explore the probability of developing cancer based on different lifestyles.

# %% [markdown]
# ## Data Collection

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#loading the dataset
df = pd.read_csv('cancer-probabilities.csv')

# %%
df.head()
# Out:
#    Sr No. Smoking Habit Drinking Habit Biking Habit Walking Habit  \
# 0       1         Heavy       Frequent          Low           Low
# 1       2    Occasional       Moderate         High          High
# 2       3           NaN            NaN         High          High
# 3       4         Heavy       Frequent          Low           Low
# 4       5      Moderate     Occasional       Medium        Medium
#
#   Jogging Habit  Probability of Cancer
# 0           Low                    0.8
# 1          High                    0.2
# 2          High                    0.1
# 3           Low                    0.9
# 4        Medium                    0.4

# %%
df.shape
# Out:
# (50, 7)

# %%
print(f"The dataset has {df.shape[0]} rows and {df.shape[1]} columns.")
# Out:
# The dataset has 50 rows and 7 columns.

# %%
print(df['Smoking Habit'].unique())
print(df['Drinking Habit'].unique())
print(df['Biking Habit'].unique())
print(df['Walking Habit'].unique())
print(df['Jogging Habit'].unique())
# Out:
# ['Heavy' 'Occasional' nan 'Moderate']
# ['Frequent' 'Moderate' nan 'Occasional']
# ['Low' 'High' 'Medium']
# ['Low' 'High' 'Medium']
# ['Low' 'High' 'Medium']

# %% [markdown]
# ## Dataset Information
#
#
# *   Smoking Habit: Heavy, Moderate, Occasional
# *   Drinking Habit: Frequent, Moderate, Occasional
# *   Biking Habit:Low, Medium, High
# *   Walking Habit:Low, Medium, High
# *   Jogging Habit:Low, Medium, High

# %% [markdown]
# ## Data Checks to Perform
#
#
# *   Check Missing values
# *   Check data type
# *   Check the number of unique values of each column
# *   Check statistics of dataset
# *   Check various categories present in the different categorical column

# %%
# Check missing values

df.isna().sum()
# Out:
# Sr No.                    0
# Smoking Habit            16
# Drinking Habit           16
# Biking Habit              0
# Walking Habit             0
# Jogging Habit             0
# Probability of Cancer     0
# dtype: int64

# %%
# check if any rows has all the missing values
all_missing = df.isna().all(axis=1)

# Count the number of rows with all NaN values
all_missing.sum()
# Out:
# 0

# %%
# Check if any row has all NaN values
any_all_missing = all_missing.any()

any_all_missing
# Out:
# False

# %%
# handling Missing values using simple imputer
from sklearn.impute import SimpleImputer
import numpy as np

imputer = SimpleImputer(missing_values = np.nan,
                        strategy ='most_frequent')

# %%
# For Categorical Columns
cat_cols = df.loc[:,df.dtypes==object].columns
cat_cols
# Out:
# Index(['Smoking Habit', 'Drinking Habit', 'Biking Habit', 'Walking Habit',
#        'Jogging Habit'],
#       dtype='object')

# %%
imputer.fit(df[cat_cols])

df[cat_cols] = imputer.transform(df[cat_cols])

# check if any missing value present
df.isna().values.any()
# Out:
# False

# %%
df
# Out:
#     Sr No. Smoking Habit Drinking Habit Biking Habit Walking Habit  \
# 0        1         Heavy       Frequent          Low           Low
# 1        2    Occasional       Moderate         High          High
# 2        3         Heavy       Frequent         High          High
# 3        4         Heavy       Frequent          Low           Low
# 4        5      Moderate     Occasional       Medium        Medium
# 5        6         Heavy       Frequent         High          High
# 6        7         Heavy       Frequent          Low           Low
# 7        8      Moderate     Occasional       Medium        Medium
# 8        9         Heavy       Frequent         High          High
# 9       10         Heavy       Frequent          Low           Low
# 10      11      Moderate     Occasional       Medium        Medium
# 11      12         Heavy       Frequent         High          High
# 12      13         Heavy       Frequent          Low           Low
# ...

# %%
# Drop irrelevant column
# drop column 'Sr No.'
df.drop('Sr No.', axis=1, inplace=True)

# %%
df
# Out:
#    Smoking Habit Drinking Habit Biking Habit Walking Habit Jogging Habit  \
# 0          Heavy       Frequent          Low           Low           Low
# 1     Occasional       Moderate         High          High          High
# 2          Heavy       Frequent         High          High          High
# 3          Heavy       Frequent          Low           Low           Low
# 4       Moderate     Occasional       Medium        Medium        Medium
# 5          Heavy       Frequent         High          High          High
# 6          Heavy       Frequent          Low           Low           Low
# 7       Moderate     Occasional       Medium        Medium        Medium
# 8          Heavy       Frequent         High          High          High
# 9          Heavy       Frequent          Low           Low           Low
# 10      Moderate     Occasional       Medium        Medium        Medium
# 11         Heavy       Frequent         High          High          High
# ...

# %%
# check data types

#check null and dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Smoking Habit          50 non-null     object
#  1   Drinking Habit         50 non-null     object
#  2   Biking Habit           50 non-null     object
#  3   Walking Habit          50 non-null     object
#  4   Jogging Habit          50 non-null     object
#  5   Probability of Cancer  50 non-null     float64
# dtypes: float64(1), object(5)
# memory usage: 2.5+ KB

# %%
# checking number of unique values in each column
df.nunique()
# Out:
# Smoking Habit             3
# Drinking Habit            3
# Biking Habit              3
# Walking Habit             3
# Jogging Habit             3
# Probability of Cancer    15
# dtype: int64

# %%
# check statistics of categorical dataset
df.describe(include=[object])
# Out:
#        Smoking Habit Drinking Habit Biking Habit Walking Habit Jogging Habit
# count             50             50           50            50            50
# unique             3              3            3             3             3
# top            Heavy       Frequent          Low           Low           Low
# freq              33             33           17            17            17

# %%
# check statistics of numerical dataset
df.describe()
# Out:
#        Probability of Cancer
# count              50.000000
# mean                0.407200
# std                 0.325501
# min                 0.010000
# 25%                 0.050000
# 50%                 0.375000
# 75%                 0.750000
# max                 0.900000

# %%
# Exploring data
df.head()
# Out:
#   Smoking Habit Drinking Habit Biking Habit Walking Habit Jogging Habit  \
# 0         Heavy       Frequent          Low           Low           Low
# 1    Occasional       Moderate         High          High          High
# 2         Heavy       Frequent         High          High          High
# 3         Heavy       Frequent          Low           Low           Low
# 4      Moderate     Occasional       Medium        Medium        Medium
#
#    Probability of Cancer
# 0                    0.8
# 1                    0.2
# 2                    0.1
# 3                    0.9
# 4                    0.4

# %%
# Define Numerical and Categorical Columns
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# %%
print("We have {} numerical features : {}".format(len(numeric_features),numeric_features))
print("\nWe have {} categorical features : {}\n".format(len(categorical_features), categorical_features))

df.head(n=2)
# Out:
# We have 1 numerical features : ['Probability of Cancer']
#
# We have 5 categorical features : ['Smoking Habit', 'Drinking Habit', 'Biking Habit', 'Walking Habit', 'Jogging Habit']
#   Smoking Habit Drinking Habit Biking Habit Walking Habit Jogging Habit  \
# 0         Heavy       Frequent          Low           Low           Low
# 1    Occasional       Moderate         High          High          High
#
#    Probability of Cancer
# 0                    0.8
# 1                    0.2

# %%
# Exploring Data (Visualization)

# %%
import matplotlib.pyplot as plt

data_by_smoking_habit = df.groupby('Smoking Habit').count()
data_by_smoking_habit
# Out:
#                Drinking Habit  Biking Habit  Walking Habit  Jogging Habit  \
# Smoking Habit
# Heavy                      33            33             33             33
# Moderate                   16            16             16             16
# Occasional                  1             1              1              1
#
#                Probability of Cancer
# Smoking Habit
# Heavy                             33
# Moderate                          16
# Occasional                         1

# %%
# show value of each bar
def add_labls_price(x,y):
  for k in range(len(x)):
    plt.text(k,y[k],str(round(y[k],2)),ha='center',va='bottom')


# plot bar chart
drinking_habit_value_counts = df['Drinking Habit'].value_counts()

x_labels_list = drinking_habit_value_counts.index
x = np.arange(len(x_labels_list))
width=0.4


plt.plot()
plt.title('Distribution of Drinking Habit')
plt.bar(drinking_habit_value_counts.index, drinking_habit_value_counts.values)

add_labls_price(x,drinking_habit_value_counts.values)

plt.xlabel('Drinking Habit')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
# Alternatively
# plot bar chart
smoking_habit_value_counts = df['Smoking Habit'].value_counts()
plt.plot()
plt.title('Distribution of Smoking Habit')
plt.bar(smoking_habit_value_counts.index, smoking_habit_value_counts.values)
plt.xlabel('Smoking Habit')
plt.ylabel('Count')

# Adding counts on top of the bars
for idx, value in enumerate(smoking_habit_value_counts.values):
    plt.text(idx, value, str(value), ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
# Convert 'Smoking Habit' to numerical values for easier comparison
smoking_mapping = {'Heavy': 3, 'Moderate': 2, 'Occasional': 1}
df['Smoking Habit (Numeric)'] = df['Smoking Habit'].map(smoking_mapping)

drinking_mapping = {'Frequent': 3, 'Moderate': 2, 'Occasional': 1}
df['Drinking Habit (Numeric)'] = df['Drinking Habit'].map(drinking_mapping)

biking_mapping = {'High': 3, 'Medium': 2, 'Low': 1}
df['Biking Habit (Numeric)'] = df['Biking Habit'].map(biking_mapping)

walking_mapping = {'High': 3, 'Medium': 2, 'Low': 1}
df['Walking Habit (Numeric)'] = df['Walking Habit'].map(walking_mapping)

jogging_mapping = {'High': 3, 'Medium': 2, 'Low': 1}
df['Jogging Habit (Numeric)'] = df['Jogging Habit'].map(jogging_mapping)

# %%
#correlation between probability of cancer and all the habit
import seaborn as sns
import numpy as np

# Creating a DataFrame for correlations between all habits and cancer probability
correlation_matrix = df[['Smoking Habit (Numeric)', 'Drinking Habit (Numeric)', 'Biking Habit (Numeric)', 'Walking Habit (Numeric)', 'Jogging Habit (Numeric)', 'Probability of Cancer']].corr()

# Creating a heatmap to visualize the correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt=".2f")
plt.title('Correlation Matrix of Habits and Probability of Cancer')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##Here are the correlations between various habits and the probability of cancer:
#
# Smoking Habit:
# 0.12
# (weak positive correlation)
#
# Drinking Habit:
# 0.10
# (weak positive correlation)
#
# Biking Habit:
# −
# 0.98
# (strong negative correlation)
#
# Walking Habit:
# −
# 0.98
# (strong negative correlation)
#
# Jogging Habit:
# −
# 0.98
# (strong negative correlation)
#
# ##This analysis shows that higher levels of biking, walking, and jogging are strongly associated with lower cancer probability, while smoking and drinking shows a weaker positive correlation with cancer risk.

# %%
# Splitting Features and Label

# Label Data
Y = df['Probability of Cancer']

# Features Data
X = df.select_dtypes(include="object")
#features_cols = X.columns

# %%
num_features = X.select_dtypes(exclude="object").columns
cat_features = X.select_dtypes(include="object").columns

# %%
# Data Preprocessing (Scaling)
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

scaler = StandardScaler()
oh_encoder = OneHotEncoder()

preprocessor = ColumnTransformer(
    [
        ("OneHotEncoder", oh_encoder, cat_features),
         ("StandardScaler", scaler, num_features),
    ]
)

# %%
X = preprocessor.fit_transform(X)

# %%
X.shape
# Out:
# (50, 15)

# %%
# separate dataset into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,random_state=42)
X_train.shape, X_test.shape
# Out:
# ((40, 15), (10, 15))

# %%
# pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 6.0 MB/s eta 0:00:00
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Ridge,Lasso
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
from catboost import CatBoostRegressor
from xgboost import XGBRegressor

# %% [markdown]
# #### Create an Evaluate Function to give all metrics after model Training

# %%
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Lasso": Lasso(),
    "Ridge": Ridge(),
    "K-Neighbors Regressor": KNeighborsRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest Regressor": RandomForestRegressor(),
    "XGBRegressor": XGBRegressor(),
    "CatBoosting Regressor": CatBoostRegressor(verbose=False),
    "AdaBoost Regressor": AdaBoostRegressor()
}

# %%
model_list = []
r2_list =[]

for i in range(len(list(models))):
  model = list(models.values())[i]

  #Train the model
  model.fit(X_train,y_train)

  #Make prediction
  y_train_pred = model.predict(X_train)
  y_test_pred = model.predict(X_test)

  #Evaluate Train and Test dataset
  model_train_mae , model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)

  model_test_mae , model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)

  print(list(models.keys())[i])
  model_list.append(list(models.keys())[i])

  print('Model performance for Training set')
  print("- Root Mean Squared Error: {:.4f}".format(model_train_rmse))
  print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
  print("- R2 Score: {:.4f}".format(model_train_r2))

  print('----------------------------------')

  print('Model performance for Test set')
  print("- Root Mean Squared Error: {:.4f}".format(model_test_rmse))
  print("- Mean Absolute Error: {:.4f}".format(model_test_mae))
  print("- R2 Score: {:.4f}".format(model_test_r2))
  r2_list.append(model_test_r2)

  print('='*35)
  print('\n')
# Out:
# Linear Regression
# Model performance for Training set
# - Root Mean Squared Error: 0.0503
# - Mean Absolute Error: 0.0379
# - R2 Score: 0.9747
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.0551
# - Mean Absolute Error: 0.0412
# - R2 Score: 0.9743
# ...
#
#
# Lasso
# Model performance for Training set
# - Root Mean Squared Error: 0.3159
# - Mean Absolute Error: 0.2674
# - R2 Score: 0.0000
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.3469
# - Mean Absolute Error: 0.3045
# - R2 Score: -0.0189
# ...
#
#
# Ridge
# Model performance for Training set
# - Root Mean Squared Error: 0.0514
# - Mean Absolute Error: 0.0410
# - R2 Score: 0.9736
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.0586
# - Mean Absolute Error: 0.0447
# - R2 Score: 0.9709
# ...
#
#
# K-Neighbors Regressor
# Model performance for Training set
# ...

# %% [markdown]
# ##Results

# %%
pd.DataFrame(list(zip(model_list, r2_list)), columns=['Model Name', 'R2_Score']).sort_values(by=["R2_Score"],ascending=False)
# Out:
#                 Model Name  R2_Score
# 8       AdaBoost Regressor  0.975810
# 0        Linear Regression  0.974308
# 4            Decision Tree  0.974308
# 7    CatBoosting Regressor  0.974305
# 6             XGBRegressor  0.974265
# 5  Random Forest Regressor  0.974080
# 3    K-Neighbors Regressor  0.971551
# 2                    Ridge  0.970928
# 1                    Lasso -0.018903

# %% [markdown]
# ### Using Linear Regressor

# %%
lin_model = LinearRegression(fit_intercept=True)
lin_model = lin_model.fit(X_train, y_train)
y_pred = lin_model.predict(X_test)
score = r2_score(y_test, y_pred)*100
print(" Accuracy of the model is %.2f" %score)
# Out:
#  Accuracy of the model is 97.43

# %% [markdown]
# #### Difference between Actual and Predicted Values

# %%
pred_df=pd.DataFrame({'Actual Value':y_test,'Predicted Value':np.round(y_pred,2),'Difference':y_test-np.round(y_pred,2)})
pred_df
# Out:
#     Actual Value  Predicted Value  Difference
# 13          0.35             0.38       -0.03
# 39          0.90             0.80        0.10
# 30          0.90             0.80        0.10
# 45          0.80             0.80        0.00
# 17          0.05             0.03        0.02
# 48          0.75             0.80       -0.05
# 26          0.03             0.03        0.00
# 25          0.35             0.38       -0.03
# 32          0.02             0.03       -0.01
# 19          0.30             0.38       -0.08

# %% [markdown]
# ###Using AdaBoostRegressor

# %%
# Initialize the AdaBoostRegressor model
adaboost_model = AdaBoostRegressor()

# Train the model
adaboost_model = adaboost_model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = adaboost_model.predict(X_test)

# Calculate the R-squared score (accuracy)
score = r2_score(y_test, y_pred) * 100

# Print the accuracy of the model
print("Accuracy of the model is %.2f%%" % score)
# Out:
# Accuracy of the model is 97.51%

# %% [markdown]
# #### Difference between Actual and Predicted Values

# %%
pred_df=pd.DataFrame({'Actual Value':y_test,'Predicted Value':np.round(y_pred,2),'Difference':y_test-np.round(y_pred,2)})
pred_df
# Out:
#     Actual Value  Predicted Value  Difference
# 13          0.35             0.37       -0.02
# 39          0.90             0.80        0.10
# 30          0.90             0.80        0.10
# 45          0.80             0.80        0.00
# 17          0.05             0.04        0.01
# 48          0.75             0.80       -0.05
# 26          0.03             0.04       -0.01
# 25          0.35             0.37       -0.02
# 32          0.02             0.04       -0.02
# 19          0.30             0.37       -0.07
